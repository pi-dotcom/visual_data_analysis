# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fert = pd.read_csv('gapminder_total_fertility.csv',',')
fert
# Out:
#       Total fertility rate  1800  1801  1802  1803  1804  1805  1806  1807  \
# 0                 Abkhazia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1              Afghanistan  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# 2    Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3                  Albania  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# 4                  Algeria  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
# ..                     ...   ...   ...   ...   ...   ...   ...   ...   ...
# 255             Yugoslavia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 256                 Zambia  6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71
# 257               Zimbabwe  6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75
# 258                  Åland   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 259                  Åland   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#      1808  ...  2006  2007  2008  2009  2010  2011  2012  2013  2014  2015
# 0     NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1    7.00  ...  6.70  6.46  6.20  5.93  5.66  5.40  5.14  4.90  4.68  4.47
# 2     NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3    4.60  ...  1.85  1.80  1.76  1.74  1.74  1.75  1.76  1.77  1.78  1.78
# 4    6.99  ...  2.58  2.66  2.73  2.78  2.82  2.83  2.82  2.80  2.76  2.71
# ..    ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 255   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 256  6.71  ...  5.93  5.91  5.88  5.85  5.81  5.77  5.73  5.69  5.64  5.59
# 257  6.75  ...  3.94  3.90  3.85  3.79  3.72  3.64  3.56  3.49  3.41  3.35
# 258   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 259   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [260 rows x 217 columns]

# %%
life = pd.read_excel('gapminder_lifeexpectancy.xlsx')
life
# Out:
#            Life expectancy   1800   1801   1802   1803   1804   1805   1806  \
# 0                 Abkhazia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1              Afghanistan  28.21  28.20  28.19  28.18  28.17  28.16  28.15
# 2    Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3                  Albania  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# 4                  Algeria  28.82  28.82  28.82  28.82  28.82  28.82  28.82
# ..                     ...    ...    ...    ...    ...    ...    ...    ...
# 255             Yugoslavia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 256                 Zambia  32.60  32.60  32.60  32.60  32.60  32.60  32.60
# 257               Zimbabwe  33.70  33.70  33.70  33.70  33.70  33.70  33.70
# 258                  Åland    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 259            South Sudan  26.67  26.67  26.67  26.67  26.67  26.67  26.67
#
#       1807   1808  ...  2007  2008  2009  2010  2011  2012  2013  2014  2015  \
# 0      NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1    28.14  28.13  ...  52.4  52.8  53.3  53.6  54.0  54.4  54.8  54.9  53.8
# 2      NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3    35.40  35.40  ...  76.6  76.8  77.0  77.2  77.4  77.5  77.7  77.9  78.0
# 4    28.82  28.82  ...  75.3  75.5  75.7  76.0  76.1  76.2  76.3  76.3  76.4
# ..     ...    ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 255    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 256  32.60  32.60  ...  49.0  51.1  52.3  53.1  53.7  54.7  55.6  56.3  56.7
# 257  33.70  33.70  ...  46.4  47.3  48.0  49.1  51.6  54.2  55.7  57.0  59.3
# 258    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 259  26.67  26.67  ...  55.5  55.6  55.8  56.0  55.9  56.0  56.0  56.1  56.1
#
#       2016
# 0      NaN
# 1    52.72
# 2      NaN
# 3    78.10
# 4    76.50
# ..     ...
# 255    NaN
# 256  57.10
# 257  61.69
# 258    NaN
# 259  56.10
#
# [260 rows x 218 columns]

# %%
pop = pd.read_excel('gapminder_population.xlsx')
pop
# Out:
#                                  Total population       1800       1810  \
# 0                                        Abkhazia        NaN        NaN
# 1                                     Afghanistan  3280000.0  3280000.0
# 2                           Akrotiri and Dhekelia        NaN        NaN
# 3                                         Albania   410445.0   423591.0
# 4                                         Algeria  2503218.0  2595056.0
# ..                                            ...        ...        ...
# 270                             Northern Marianas        NaN        NaN
# 271  South Georgia and the South Sandwich Islands        NaN        NaN
# 272                     US Minor Outlying Islands        NaN        NaN
# 273                                Virgin Islands        NaN        NaN
# 274                                     West Bank        NaN        NaN
#
#           1820       1830       1840       1850       1860       1870  \
# 0          NaN        NaN        NaN        NaN        NaN        NaN
# 1    3323519.0  3448982.0  3625022.0  3810047.0  3973968.0  4169690.0
# 2          NaN        NaN        NaN        NaN        NaN        NaN
# 3     438671.0   457234.0   478227.0   506889.0   552800.0   610036.0
# 4    2713079.0  2880355.0  3082721.0  3299305.0  3536468.0  3811028.0
# ..         ...        ...        ...        ...        ...        ...
# 270        NaN        NaN        NaN        NaN        NaN        NaN
# 271        NaN        NaN        NaN        NaN        NaN        NaN
# 272        NaN        NaN        NaN        NaN        NaN        NaN
# 273        NaN        NaN        NaN        NaN        NaN        NaN
# 274        NaN        NaN        NaN        NaN        NaN        NaN
#
#           1880  ...        2006        2007        2008        2009  \
# 0          NaN  ...         NaN         NaN         NaN         NaN
# 1    4419695.0  ...  25183615.0  25877544.0  26528741.0  27207291.0
# 2          NaN  ...     15700.0     15700.0     15700.0         NaN
# 3     672544.0  ...   3050741.0   3010849.0   2968026.0   2929886.0
# 4    4143163.0  ...  33749328.0  34261971.0  34811059.0  35401790.0
# ..         ...  ...         ...         ...         ...         ...
# 270        NaN  ...         NaN         NaN         NaN         NaN
# 271        NaN  ...         NaN         NaN         NaN         NaN
# 272        NaN  ...         NaN         NaN         NaN         NaN
# 273        NaN  ...         NaN         NaN         NaN         NaN
# 274        NaN  ...         NaN         NaN         NaN         NaN
#
#            2010        2011        2012        2013        2014        2015
# 0           NaN         NaN         NaN         NaN         NaN         NaN
# 1    27962207.0  28809167.0  29726803.0  30682500.0  31627506.0  32526562.0
# 2           NaN         NaN         NaN         NaN         NaN         NaN
# 3     2901883.0   2886010.0   2880667.0   2883281.0   2889676.0   2896679.0
# 4    36036159.0  36717132.0  37439427.0  38186135.0  38934334.0  39666519.0
# ..          ...         ...         ...         ...         ...         ...
# 270         NaN         NaN         NaN         NaN         NaN         NaN
# 271         NaN         NaN         NaN         NaN         NaN         NaN
# 272         NaN         NaN         NaN         NaN         NaN         NaN
# 273         NaN         NaN         NaN         NaN         NaN         NaN
# 274         NaN         NaN         NaN         NaN         NaN         NaN
#
# [275 rows x 82 columns]

# %%
print(life.shape)
# Out:
# (260, 218)

# %%
print(fert.shape)
# Out:
# (260, 217)

# %%
print(pop.shape)
# Out:
# (275, 82)

# %%
fert = fert.set_index('Total fertility rate')
fert
# Out:
#                        1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# Total fertility rate
# Abkhazia                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# Algeria                6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
# ...                     ...   ...   ...   ...   ...   ...   ...   ...   ...
# Yugoslavia              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Zambia                 6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71
# Zimbabwe               6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75
# Åland                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Åland                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                        1809  ...  2006  2007  2008  2009  2010  2011  2012  \
# Total fertility rate         ...
# Abkhazia                NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  ...  6.70  6.46  6.20  5.93  5.66  5.40  5.14
# Akrotiri and Dhekelia   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  ...  1.85  1.80  1.76  1.74  1.74  1.75  1.76
# Algeria                6.99  ...  2.58  2.66  2.73  2.78  2.82  2.83  2.82
# ...                     ...  ...   ...   ...   ...   ...   ...   ...   ...
# Yugoslavia              NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Zambia                 6.71  ...  5.93  5.91  5.88  5.85  5.81  5.77  5.73
# Zimbabwe               6.75  ...  3.94  3.90  3.85  3.79  3.72  3.64  3.56
# Åland                   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Åland                   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                        2013  2014  2015
# Total fertility rate
# Abkhazia                NaN   NaN   NaN
# Afghanistan            4.90  4.68  4.47
# Akrotiri and Dhekelia   NaN   NaN   NaN
# Albania                1.77  1.78  1.78
# Algeria                2.80  2.76  2.71
# ...                     ...   ...   ...
# Yugoslavia              NaN   NaN   NaN
# Zambia                 5.69  5.64  5.59
# Zimbabwe               3.49  3.41  3.35
# Åland                   NaN   NaN   NaN
# Åland                   NaN   NaN   NaN
#
# [260 rows x 216 columns]

# %%
life = life.set_index('Life expectancy')
life
# Out:
#                         1800   1801   1802   1803   1804   1805   1806   1807  \
# Life expectancy
# Abkhazia                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Afghanistan            28.21  28.20  28.19  28.18  28.17  28.16  28.15  28.14
# Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Albania                35.40  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# Algeria                28.82  28.82  28.82  28.82  28.82  28.82  28.82  28.82
# ...                      ...    ...    ...    ...    ...    ...    ...    ...
# Yugoslavia               NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Zambia                 32.60  32.60  32.60  32.60  32.60  32.60  32.60  32.60
# Zimbabwe               33.70  33.70  33.70  33.70  33.70  33.70  33.70  33.70
# Åland                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# South Sudan            26.67  26.67  26.67  26.67  26.67  26.67  26.67  26.67
#
#                         1808   1809  ...  2007  2008  2009  2010  2011  2012  \
# Life expectancy                      ...
# Abkhazia                 NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            28.13  28.12  ...  52.4  52.8  53.3  53.6  54.0  54.4
# Akrotiri and Dhekelia    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                35.40  35.40  ...  76.6  76.8  77.0  77.2  77.4  77.5
# Algeria                28.82  28.82  ...  75.3  75.5  75.7  76.0  76.1  76.2
# ...                      ...    ...  ...   ...   ...   ...   ...   ...   ...
# Yugoslavia               NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# Zambia                 32.60  32.60  ...  49.0  51.1  52.3  53.1  53.7  54.7
# Zimbabwe               33.70  33.70  ...  46.4  47.3  48.0  49.1  51.6  54.2
# Åland                    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# South Sudan            26.67  26.67  ...  55.5  55.6  55.8  56.0  55.9  56.0
#
#                        2013  2014  2015   2016
# Life expectancy
# Abkhazia                NaN   NaN   NaN    NaN
# Afghanistan            54.8  54.9  53.8  52.72
# Akrotiri and Dhekelia   NaN   NaN   NaN    NaN
# Albania                77.7  77.9  78.0  78.10
# Algeria                76.3  76.3  76.4  76.50
# ...                     ...   ...   ...    ...
# Yugoslavia              NaN   NaN   NaN    NaN
# Zambia                 55.6  56.3  56.7  57.10
# Zimbabwe               55.7  57.0  59.3  61.69
# Åland                   NaN   NaN   NaN    NaN
# South Sudan            56.0  56.1  56.1  56.10
#
# [260 rows x 217 columns]

# %%
pop = pop.set_index('Total population')
pop
# Out:
#                                                    1800       1810       1820  \
# Total population
# Abkhazia                                            NaN        NaN        NaN
# Afghanistan                                   3280000.0  3280000.0  3323519.0
# Akrotiri and Dhekelia                               NaN        NaN        NaN
# Albania                                        410445.0   423591.0   438671.0
# Algeria                                       2503218.0  2595056.0  2713079.0
# ...                                                 ...        ...        ...
# Northern Marianas                                   NaN        NaN        NaN
# South Georgia and the South Sandwich Islands        NaN        NaN        NaN
# US Minor Outlying Islands                           NaN        NaN        NaN
# Virgin Islands                                      NaN        NaN        NaN
# West Bank                                           NaN        NaN        NaN
#
#                                                    1830       1840       1850  \
# Total population
# Abkhazia                                            NaN        NaN        NaN
# Afghanistan                                   3448982.0  3625022.0  3810047.0
# Akrotiri and Dhekelia                               NaN        NaN        NaN
# Albania                                        457234.0   478227.0   506889.0
# Algeria                                       2880355.0  3082721.0  3299305.0
# ...                                                 ...        ...        ...
# Northern Marianas                                   NaN        NaN        NaN
# South Georgia and the South Sandwich Islands        NaN        NaN        NaN
# US Minor Outlying Islands                           NaN        NaN        NaN
# Virgin Islands                                      NaN        NaN        NaN
# West Bank                                           NaN        NaN        NaN
#
#                                                    1860       1870       1880  \
# Total population
# Abkhazia                                            NaN        NaN        NaN
# Afghanistan                                   3973968.0  4169690.0  4419695.0
# Akrotiri and Dhekelia                               NaN        NaN        NaN
# Albania                                        552800.0   610036.0   672544.0
# Algeria                                       3536468.0  3811028.0  4143163.0
# ...                                                 ...        ...        ...
# Northern Marianas                                   NaN        NaN        NaN
# South Georgia and the South Sandwich Islands        NaN        NaN        NaN
# US Minor Outlying Islands                           NaN        NaN        NaN
# Virgin Islands                                      NaN        NaN        NaN
# West Bank                                           NaN        NaN        NaN
#
#                                                    1890  ...        2006  \
# Total population                                         ...
# Abkhazia                                            NaN  ...         NaN
# Afghanistan                                   4710171.0  ...  25183615.0
# Akrotiri and Dhekelia                               NaN  ...     15700.0
# Albania                                        741688.0  ...   3050741.0
# Algeria                                       4525691.0  ...  33749328.0
# ...                                                 ...  ...         ...
# Northern Marianas                                   NaN  ...         NaN
# South Georgia and the South Sandwich Islands        NaN  ...         NaN
# US Minor Outlying Islands                           NaN  ...         NaN
# Virgin Islands                                      NaN  ...         NaN
# West Bank                                           NaN  ...         NaN
#
#                                                     2007        2008  \
# Total population
# Abkhazia                                             NaN         NaN
# Afghanistan                                   25877544.0  26528741.0
# Akrotiri and Dhekelia                            15700.0     15700.0
# Albania                                        3010849.0   2968026.0
# Algeria                                       34261971.0  34811059.0
# ...                                                  ...         ...
# Northern Marianas                                    NaN         NaN
# South Georgia and the South Sandwich Islands         NaN         NaN
# US Minor Outlying Islands                            NaN         NaN
# Virgin Islands                                       NaN         NaN
# West Bank                                            NaN         NaN
#
#                                                     2009        2010  \
# Total population
# Abkhazia                                             NaN         NaN
# Afghanistan                                   27207291.0  27962207.0
# Akrotiri and Dhekelia                                NaN         NaN
# Albania                                        2929886.0   2901883.0
# Algeria                                       35401790.0  36036159.0
# ...                                                  ...         ...
# Northern Marianas                                    NaN         NaN
# South Georgia and the South Sandwich Islands         NaN         NaN
# US Minor Outlying Islands                            NaN         NaN
# Virgin Islands                                       NaN         NaN
# West Bank                                            NaN         NaN
#
#                                                     2011        2012  \
# Total population
# Abkhazia                                             NaN         NaN
# Afghanistan                                   28809167.0  29726803.0
# Akrotiri and Dhekelia                                NaN         NaN
# Albania                                        2886010.0   2880667.0
# Algeria                                       36717132.0  37439427.0
# ...                                                  ...         ...
# Northern Marianas                                    NaN         NaN
# South Georgia and the South Sandwich Islands         NaN         NaN
# US Minor Outlying Islands                            NaN         NaN
# Virgin Islands                                       NaN         NaN
# West Bank                                            NaN         NaN
#
#                                                     2013        2014  \
# Total population
# Abkhazia                                             NaN         NaN
# Afghanistan                                   30682500.0  31627506.0
# Akrotiri and Dhekelia                                NaN         NaN
# Albania                                        2883281.0   2889676.0
# Algeria                                       38186135.0  38934334.0
# ...                                                  ...         ...
# Northern Marianas                                    NaN         NaN
# South Georgia and the South Sandwich Islands         NaN         NaN
# US Minor Outlying Islands                            NaN         NaN
# Virgin Islands                                       NaN         NaN
# West Bank                                            NaN         NaN
#
#                                                     2015
# Total population
# Abkhazia                                             NaN
# Afghanistan                                   32526562.0
# Akrotiri and Dhekelia                                NaN
# Albania                                        2896679.0
# Algeria                                       39666519.0
# ...                                                  ...
# Northern Marianas                                    NaN
# South Georgia and the South Sandwich Islands         NaN
# US Minor Outlying Islands                            NaN
# Virgin Islands                                       NaN
# West Bank                                            NaN
#
# [275 rows x 81 columns]

# %%
life.columns = life.columns.astype(int)
life.columns
# Out:
# Int64Index([1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809,
#             ...
#             2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016],
#            dtype='int64', length=217)

# %%
fert.columns = fert.columns.astype(int)
fert.columns
# Out:
# Int64Index([1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809,
#             ...
#             2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015],
#            dtype='int64', length=216)

# %%
pop.columns = pop.columns.astype(int)
pop.columns
# Out:
# Int64Index([1800, 1810, 1820, 1830, 1840, 1850, 1860, 1870, 1880, 1890, 1900,
#             1910, 1920, 1930, 1940, 1950, 1951, 1952, 1953, 1954, 1955, 1956,
#             1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967,
#             1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978,
#             1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989,
#             1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#             2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015],
#            dtype='int64')

# %%
fert.index.name = 'Country'
life.index.name = 'Country'
pop.index.name = 'Country'

# %%
fert
# Out:
#                        1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# Country
# Abkhazia                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# Algeria                6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
# ...                     ...   ...   ...   ...   ...   ...   ...   ...   ...
# Yugoslavia              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Zambia                 6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71
# Zimbabwe               6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75
# Åland                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Åland                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                        1809  ...  2006  2007  2008  2009  2010  2011  2012  \
# Country                      ...
# Abkhazia                NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  ...  6.70  6.46  6.20  5.93  5.66  5.40  5.14
# Akrotiri and Dhekelia   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  ...  1.85  1.80  1.76  1.74  1.74  1.75  1.76
# Algeria                6.99  ...  2.58  2.66  2.73  2.78  2.82  2.83  2.82
# ...                     ...  ...   ...   ...   ...   ...   ...   ...   ...
# Yugoslavia              NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Zambia                 6.71  ...  5.93  5.91  5.88  5.85  5.81  5.77  5.73
# Zimbabwe               6.75  ...  3.94  3.90  3.85  3.79  3.72  3.64  3.56
# Åland                   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Åland                   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                        2013  2014  2015
# Country
# Abkhazia                NaN   NaN   NaN
# Afghanistan            4.90  4.68  4.47
# Akrotiri and Dhekelia   NaN   NaN   NaN
# Albania                1.77  1.78  1.78
# Algeria                2.80  2.76  2.71
# ...                     ...   ...   ...
# Yugoslavia              NaN   NaN   NaN
# Zambia                 5.69  5.64  5.59
# Zimbabwe               3.49  3.41  3.35
# Åland                   NaN   NaN   NaN
# Åland                   NaN   NaN   NaN
#
# [260 rows x 216 columns]

# %%
life
# Out:
#                         1800   1801   1802   1803   1804   1805   1806   1807  \
# Country
# Abkhazia                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Afghanistan            28.21  28.20  28.19  28.18  28.17  28.16  28.15  28.14
# Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Albania                35.40  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# Algeria                28.82  28.82  28.82  28.82  28.82  28.82  28.82  28.82
# ...                      ...    ...    ...    ...    ...    ...    ...    ...
# Yugoslavia               NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Zambia                 32.60  32.60  32.60  32.60  32.60  32.60  32.60  32.60
# Zimbabwe               33.70  33.70  33.70  33.70  33.70  33.70  33.70  33.70
# Åland                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# South Sudan            26.67  26.67  26.67  26.67  26.67  26.67  26.67  26.67
#
#                         1808   1809  ...  2007  2008  2009  2010  2011  2012  \
# Country                              ...
# Abkhazia                 NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            28.13  28.12  ...  52.4  52.8  53.3  53.6  54.0  54.4
# Akrotiri and Dhekelia    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                35.40  35.40  ...  76.6  76.8  77.0  77.2  77.4  77.5
# Algeria                28.82  28.82  ...  75.3  75.5  75.7  76.0  76.1  76.2
# ...                      ...    ...  ...   ...   ...   ...   ...   ...   ...
# Yugoslavia               NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# Zambia                 32.60  32.60  ...  49.0  51.1  52.3  53.1  53.7  54.7
# Zimbabwe               33.70  33.70  ...  46.4  47.3  48.0  49.1  51.6  54.2
# Åland                    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# South Sudan            26.67  26.67  ...  55.5  55.6  55.8  56.0  55.9  56.0
#
#                        2013  2014  2015   2016
# Country
# Abkhazia                NaN   NaN   NaN    NaN
# Afghanistan            54.8  54.9  53.8  52.72
# Akrotiri and Dhekelia   NaN   NaN   NaN    NaN
# Albania                77.7  77.9  78.0  78.10
# Algeria                76.3  76.3  76.4  76.50
# ...                     ...   ...   ...    ...
# Yugoslavia              NaN   NaN   NaN    NaN
# Zambia                 55.6  56.3  56.7  57.10
# Zimbabwe               55.7  57.0  59.3  61.69
# Åland                   NaN   NaN   NaN    NaN
# South Sudan            56.0  56.1  56.1  56.10
#
# [260 rows x 217 columns]

# %%
pop
# Out:
#                                                    1800       1810       1820  \
# Country
# Abkhazia                                            NaN        NaN        NaN
# Afghanistan                                   3280000.0  3280000.0  3323519.0
# Akrotiri and Dhekelia                               NaN        NaN        NaN
# Albania                                        410445.0   423591.0   438671.0
# Algeria                                       2503218.0  2595056.0  2713079.0
# ...                                                 ...        ...        ...
# Northern Marianas                                   NaN        NaN        NaN
# South Georgia and the South Sandwich Islands        NaN        NaN        NaN
# US Minor Outlying Islands                           NaN        NaN        NaN
# Virgin Islands                                      NaN        NaN        NaN
# West Bank                                           NaN        NaN        NaN
#
#                                                    1830       1840       1850  \
# Country
# Abkhazia                                            NaN        NaN        NaN
# Afghanistan                                   3448982.0  3625022.0  3810047.0
# Akrotiri and Dhekelia                               NaN        NaN        NaN
# Albania                                        457234.0   478227.0   506889.0
# Algeria                                       2880355.0  3082721.0  3299305.0
# ...                                                 ...        ...        ...
# Northern Marianas                                   NaN        NaN        NaN
# South Georgia and the South Sandwich Islands        NaN        NaN        NaN
# US Minor Outlying Islands                           NaN        NaN        NaN
# Virgin Islands                                      NaN        NaN        NaN
# West Bank                                           NaN        NaN        NaN
#
#                                                    1860       1870       1880  \
# Country
# Abkhazia                                            NaN        NaN        NaN
# Afghanistan                                   3973968.0  4169690.0  4419695.0
# Akrotiri and Dhekelia                               NaN        NaN        NaN
# Albania                                        552800.0   610036.0   672544.0
# Algeria                                       3536468.0  3811028.0  4143163.0
# ...                                                 ...        ...        ...
# Northern Marianas                                   NaN        NaN        NaN
# South Georgia and the South Sandwich Islands        NaN        NaN        NaN
# US Minor Outlying Islands                           NaN        NaN        NaN
# Virgin Islands                                      NaN        NaN        NaN
# West Bank                                           NaN        NaN        NaN
#
#                                                    1890  ...        2006  \
# Country                                                  ...
# Abkhazia                                            NaN  ...         NaN
# Afghanistan                                   4710171.0  ...  25183615.0
# Akrotiri and Dhekelia                               NaN  ...     15700.0
# Albania                                        741688.0  ...   3050741.0
# Algeria                                       4525691.0  ...  33749328.0
# ...                                                 ...  ...         ...
# Northern Marianas                                   NaN  ...         NaN
# South Georgia and the South Sandwich Islands        NaN  ...         NaN
# US Minor Outlying Islands                           NaN  ...         NaN
# Virgin Islands                                      NaN  ...         NaN
# West Bank                                           NaN  ...         NaN
#
#                                                     2007        2008  \
# Country
# Abkhazia                                             NaN         NaN
# Afghanistan                                   25877544.0  26528741.0
# Akrotiri and Dhekelia                            15700.0     15700.0
# Albania                                        3010849.0   2968026.0
# Algeria                                       34261971.0  34811059.0
# ...                                                  ...         ...
# Northern Marianas                                    NaN         NaN
# South Georgia and the South Sandwich Islands         NaN         NaN
# US Minor Outlying Islands                            NaN         NaN
# Virgin Islands                                       NaN         NaN
# West Bank                                            NaN         NaN
#
#                                                     2009        2010  \
# Country
# Abkhazia                                             NaN         NaN
# Afghanistan                                   27207291.0  27962207.0
# Akrotiri and Dhekelia                                NaN         NaN
# Albania                                        2929886.0   2901883.0
# Algeria                                       35401790.0  36036159.0
# ...                                                  ...         ...
# Northern Marianas                                    NaN         NaN
# South Georgia and the South Sandwich Islands         NaN         NaN
# US Minor Outlying Islands                            NaN         NaN
# Virgin Islands                                       NaN         NaN
# West Bank                                            NaN         NaN
#
#                                                     2011        2012  \
# Country
# Abkhazia                                             NaN         NaN
# Afghanistan                                   28809167.0  29726803.0
# Akrotiri and Dhekelia                                NaN         NaN
# Albania                                        2886010.0   2880667.0
# Algeria                                       36717132.0  37439427.0
# ...                                                  ...         ...
# Northern Marianas                                    NaN         NaN
# South Georgia and the South Sandwich Islands         NaN         NaN
# US Minor Outlying Islands                            NaN         NaN
# Virgin Islands                                       NaN         NaN
# West Bank                                            NaN         NaN
#
#                                                     2013        2014  \
# Country
# Abkhazia                                             NaN         NaN
# Afghanistan                                   30682500.0  31627506.0
# Akrotiri and Dhekelia                                NaN         NaN
# Albania                                        2883281.0   2889676.0
# Algeria                                       38186135.0  38934334.0
# ...                                                  ...         ...
# Northern Marianas                                    NaN         NaN
# South Georgia and the South Sandwich Islands         NaN         NaN
# US Minor Outlying Islands                            NaN         NaN
# Virgin Islands                                       NaN         NaN
# West Bank                                            NaN         NaN
#
#                                                     2015
# Country
# Abkhazia                                             NaN
# Afghanistan                                   32526562.0
# Akrotiri and Dhekelia                                NaN
# Albania                                        2896679.0
# Algeria                                       39666519.0
# ...                                                  ...
# Northern Marianas                                    NaN
# South Georgia and the South Sandwich Islands         NaN
# US Minor Outlying Islands                            NaN
# Virgin Islands                                       NaN
# West Bank                                            NaN
#
# [275 rows x 81 columns]

# %%
fert = fert.reset_index()
life = life.reset_index()
pop = pop.reset_index()

# %%
fert = fert.melt(id_vars='Country', var_name='year', value_name='Fertility rate')
fert
# Out:
#                      Country  year  Fertility rate
# 0                   Abkhazia  1800             NaN
# 1                Afghanistan  1800            7.00
# 2      Akrotiri and Dhekelia  1800             NaN
# 3                    Albania  1800            4.60
# 4                    Algeria  1800            6.99
# ...                      ...   ...             ...
# 56155             Yugoslavia  2015             NaN
# 56156                 Zambia  2015            5.59
# 56157               Zimbabwe  2015            3.35
# 56158                  Åland  2015             NaN
# 56159                  Åland  2015             NaN
#
# [56160 rows x 3 columns]

# %%
life = life.melt(id_vars='Country', var_name ='year', value_name = 'Life expectancy')
life
# Out:
#                      Country  year  Life expectancy
# 0                   Abkhazia  1800              NaN
# 1                Afghanistan  1800            28.21
# 2      Akrotiri and Dhekelia  1800              NaN
# 3                    Albania  1800            35.40
# 4                    Algeria  1800            28.82
# ...                      ...   ...              ...
# 56415             Yugoslavia  2016              NaN
# 56416                 Zambia  2016            57.10
# 56417               Zimbabwe  2016            61.69
# 56418                  Åland  2016              NaN
# 56419            South Sudan  2016            56.10
#
# [56420 rows x 3 columns]

# %%
pop = pop.melt(id_vars='Country', var_name ='year', value_name = 'Total Population')
pop
# Out:
#                                             Country  year  Total Population
# 0                                          Abkhazia  1800               NaN
# 1                                       Afghanistan  1800         3280000.0
# 2                             Akrotiri and Dhekelia  1800               NaN
# 3                                           Albania  1800          410445.0
# 4                                           Algeria  1800         2503218.0
# ...                                             ...   ...               ...
# 22270                             Northern Marianas  2015               NaN
# 22271  South Georgia and the South Sandwich Islands  2015               NaN
# 22272                     US Minor Outlying Islands  2015               NaN
# 22273                                Virgin Islands  2015               NaN
# 22274                                     West Bank  2015               NaN
#
# [22275 rows x 3 columns]

# %%
df = fert.merge(pop)
df
# Out:
#                      Country  year  Fertility rate  Total Population
# 0                   Abkhazia  1800             NaN               NaN
# 1                Afghanistan  1800            7.00         3280000.0
# 2      Akrotiri and Dhekelia  1800             NaN               NaN
# 3                    Albania  1800            4.60          410445.0
# 4                    Algeria  1800            6.99         2503218.0
# ...                      ...   ...             ...               ...
# 20974             Yugoslavia  2015             NaN               NaN
# 20975                 Zambia  2015            5.59        16211767.0
# 20976               Zimbabwe  2015            3.35        15602751.0
# 20977                  Åland  2015             NaN               NaN
# 20978                  Åland  2015             NaN               NaN
#
# [20979 rows x 4 columns]

# %%
df = df.merge(life)
df
# Out:
#                      Country  year  Fertility rate  Total Population  \
# 0                   Abkhazia  1800             NaN               NaN
# 1                Afghanistan  1800            7.00         3280000.0
# 2      Akrotiri and Dhekelia  1800             NaN               NaN
# 3                    Albania  1800            4.60          410445.0
# 4                    Algeria  1800            6.99         2503218.0
# ...                      ...   ...             ...               ...
# 20974             Yugoslavia  2015             NaN               NaN
# 20975                 Zambia  2015            5.59        16211767.0
# 20976               Zimbabwe  2015            3.35        15602751.0
# 20977                  Åland  2015             NaN               NaN
# 20978                  Åland  2015             NaN               NaN
#
#        Life expectancy
# 0                  NaN
# 1                28.21
# 2                  NaN
# 3                35.40
# 4                28.82
# ...                ...
# 20974              NaN
# 20975            56.70
# 20976            59.30
# 20977              NaN
# 20978              NaN
#
# [20979 rows x 5 columns]

# %%
df_subset = df.loc[df['year'].isin([2016])]
df_subset
# Out:
# Empty DataFrame
# Columns: [Country, year, Fertility rate, Total Population, Life expectancy]
# Index: []

# %%
if df_subset.empty:
    print('there is a data')
else:
    print('there is no data')
# Out:
# there is a data

# %%
df['year'].isin(range(1960,2016))
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 20974     True
# 20975     True
# 20976     True
# 20977     True
# 20978     True
# Name: year, Length: 20979, dtype: bool

# %%
df_all_subset = df.loc[df['year'].isin(range(1960,2016))]
x_min = df_all_subset['Life expectancy'].min()
x_max = df_all_subset['Life expectancy'].max()
y_min = df_all_subset['Fertility rate'].min()
y_max = df_all_subset['Fertility rate'].max()
z_min = df_all_subset['Total Population'].min()
z_max = df_all_subset['Total Population'].max()


for year in range(1960,1961):
    df_subset = df.loc[df['year'].isin([year])]
    if not df_subset.empty:
        X,Y = df_subset['Life expectancy'],df_subset['Fertility rate']
        yp = df_subset['Total Population']
        Z = (yp/z_max)
        my_cmap = plt.get_cmap('tab20')
        fig = plt.figure(figsize=(12,8))
        plt.scatter(X,Y,Z*1000,Z,cmap=my_cmap)
        plt.title(f'correlation between Life expectancy and Fertility rate {year} ')
        plt.xlabel('Life expectancy')
        plt.ylabel('Fertility rate')
        plt.axis((x_min, x_max, y_min, y_max))
        fig.savefig(f'lifeexpe_{year}.png')

# %%
# Out:
# gapminder_lifeexpectancy.xlsx  lifeexpe_1977.png  lifeexpe_1997.png
# gapminder_population.xlsx      lifeexpe_1978.png  lifeexpe_1998.png
# gapminder_total_fertility.csv  lifeexpe_1979.png  lifeexpe_1999.png
# lifeexpe_1960.png	       lifeexpe_1980.png  lifeexpe_2000.png
# lifeexpe_1961.png	       lifeexpe_1981.png  lifeexpe_2001.png
# lifeexpe_1962.png	       lifeexpe_1982.png  lifeexpe_2002.png
# lifeexpe_1963.png	       lifeexpe_1983.png  lifeexpe_2003.png
# lifeexpe_1964.png	       lifeexpe_1984.png  lifeexpe_2004.png
# lifeexpe_1965.png	       lifeexpe_1985.png  lifeexpe_2005.png
# lifeexpe_1966.png	       lifeexpe_1986.png  lifeexpe_2006.png
# lifeexpe_1967.png	       lifeexpe_1987.png  lifeexpe_2007.png
# lifeexpe_1968.png	       lifeexpe_1988.png  lifeexpe_2008.png
# lifeexpe_1969.png	       lifeexpe_1989.png  lifeexpe_2009.png
# lifeexpe_1970.png	       lifeexpe_1990.png  lifeexpe_2010.png
# lifeexpe_1971.png	       lifeexpe_1991.png  lifeexpe_2011.png
# lifeexpe_1972.png	       lifeexpe_1992.png  lifeexpe_2012.png
# lifeexpe_1973.png	       lifeexpe_1993.png  lifeexpe_2013.png
# lifeexpe_1974.png	       lifeexpe_1994.png  lifeexpe_2014.png
# lifeexpe_1975.png	       lifeexpe_1995.png  lifeexpe_2015.png
# lifeexpe_1976.png	       lifeexpe_1996.png  visual_data_analysis.ipynb

# %%
import imageio

images = []

for i in range(1960, 2016):
    filename = f'lifeexpe_{i}.png'
    images.append(imageio.imread(filename))

imageio.mimsave('output.gif', images, fps=5)

# %%
# !ls
# Out:
# gapminder_lifeexpectancy.xlsx  lifeexpe_1978.png  lifeexpe_1999.png
# gapminder_population.xlsx      lifeexpe_1979.png  lifeexpe_2000.png
# gapminder_total_fertility.csv  lifeexpe_1980.png  lifeexpe_2001.png
# lifeexpe_1960.png	       lifeexpe_1981.png  lifeexpe_2002.png
# lifeexpe_1961.png	       lifeexpe_1982.png  lifeexpe_2003.png
# lifeexpe_1962.png	       lifeexpe_1983.png  lifeexpe_2004.png
# lifeexpe_1963.png	       lifeexpe_1984.png  lifeexpe_2005.png
# lifeexpe_1964.png	       lifeexpe_1985.png  lifeexpe_2006.png
# lifeexpe_1965.png	       lifeexpe_1986.png  lifeexpe_2007.png
# lifeexpe_1966.png	       lifeexpe_1987.png  lifeexpe_2008.png
# lifeexpe_1967.png	       lifeexpe_1988.png  lifeexpe_2009.png
# lifeexpe_1968.png	       lifeexpe_1989.png  lifeexpe_2010.png
# lifeexpe_1969.png	       lifeexpe_1990.png  lifeexpe_2011.png
# lifeexpe_1970.png	       lifeexpe_1991.png  lifeexpe_2012.png
# lifeexpe_1971.png	       lifeexpe_1992.png  lifeexpe_2013.png
# lifeexpe_1972.png	       lifeexpe_1993.png  lifeexpe_2014.png
# lifeexpe_1973.png	       lifeexpe_1994.png  lifeexpe_2015.png
# lifeexpe_1974.png	       lifeexpe_1995.png  output.gif
# lifeexpe_1975.png	       lifeexpe_1996.png  visual_data_analysis.ipynb
# lifeexpe_1976.png	       lifeexpe_1997.png
# lifeexpe_1977.png	       lifeexpe_1998.png

# %% [markdown]
# ![output.gif](attachment:output.gif)

# %%
f = plt.figure(figsize=(12,8))

# %%
f.savefig
